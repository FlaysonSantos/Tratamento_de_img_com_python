# %% [markdown]
# #Converte imagens para tons de cinza e Binario.
#
# imagem de referencia para o tratamento renomeada de faces.jpg
#
# Url https://www.google.com/imgres?imgurl=https%3A%2F%2Fdoutorjairo.uol.com.br%2Fmedia%2F_versions%2Flegacy%2F2019%2F10%2FROSTOS700-2_widelg.jpg&imgrefurl=https%3A%2F%2Fdoutorjairo.uol.com.br%2Fleia%2Fpessoas-com-rosto-comum-sao-consideradas-mais-confiaveis-diz-estudo%2F&tbnid=1SbN56KF9chOjM&vet=12ahUKEwik3-iCtJr5AhV9M7kGHVyEDjgQMygAegQIARAp..i&docid=fuztgqFIQj1xGM&w=700&h=333&q=imagens%20de%20rostos%20de%20pessoas&hl=en&ved=2ahUKEwik3-iCtJr5AhV9M7kGHVyEDjgQMygAegQIARAp

# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('faces.jpg')

R, G, B = img[:,:,0], img[:,:,1], img[:,:,2]
imgGray = 0.2989 * R + 0.5870 * G + 0.1140 * B
plt.imshow(imgGray, cmap='gray')
plt.show()

# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('faces.jpg')

R, G, B = img[:,:,0], img[:,:,0], img[:,:,0]
imgGray = -0.01 * R + -0.01 * G + -0.01 * B
plt.imshow(imgGray, cmap='gray')
plt.show()
